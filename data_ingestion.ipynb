# %% [markdown]
# # Data Ingestion
#
# Here we perform data cleaning and data ingestion on the incoming JSON data.
#
# This was the criteria that we evaluated the redacted data against:
#
#
#
# 1. Specific Prices
# 2. Breakdown of prices
# 3. Explanation of prices (cost analysis)
# 4. How the prices are calculated
# 5. Whether or not the tender was approved
# 6. Why the tender was approved
# 7. Did the approval/disapproval of the tender contain any remarks to the price? Or was it based solely on the non-financial aspects of the tender e.g. (not meeting tender requirements, etc etc)
#
# Evaluation of Each Document:
#
#     AUTONOMOUS ROBOT Evaluation Report (No Award):
#         Specific Prices: No
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: No (Tender not approved)
#         Reasons for Tender Approval: N/A
#         Remarks Related to Price: No
#
#     Development of Financial Declaration App_SOW (Final):
#         Specific Prices: No
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Not Stated
#         Reasons for Tender Approval: N/A
#         Remarks Related to Price: N/A
#
#     Development of Mobile App- DC Inno Evaluation report V3_15Feb:
#         Specific Prices: Yes
#         Breakdown of Prices: Yes
#         Explanation of Prices: Yes
#         How Prices are Calculated: Yes
#         Tender Approval: Not Explicitly Stated
#         Reasons for Tender Approval: N/A
#         Remarks Related to Price: Yes
#
#     Evaluation Report - Sensors_caa200521:
#         Specific Prices: Yes
#         Breakdown of Prices: Yes
#         Explanation of Prices: Yes
#         How Prices are Calculated: Yes
#         Tender Approval: Conditional
#         Reasons for Tender Approval: Price negotiation
#         Remarks Related to Price: Yes
#
#     evaluation report development trial of COTS system:
#         Specific Prices: Yes
#         Breakdown of Prices: Yes
#         Explanation of Prices: Yes
#         How Prices are Calculated: Yes
#         Tender Approval: Likely
#         Reasons for Tender Approval: Price Reasonableness
#         Remarks Related to Price: Yes
#
#     EVALUATION REPORT E LEARNING SYSTEM:
#         Specific Prices: Yes
#         Breakdown of Prices: Yes
#         Explanation of Prices: Yes
#         How Prices are Calculated: Yes
#         Tender Approval: Recommended
#         Reasons for Tender Approval: Cost-effectiveness
#         Remarks Related to Price: Yes
#
#     Evaluation report for cloud based training aid software:
#         Specific Prices: Yes
#         Breakdown of Prices: Yes
#         Explanation of Prices: Yes
#         How Prices are Calculated: Yes
#         Tender Approval: Likely
#         Reasons for Tender Approval: Price Reasonableness
#         Remarks Related to Price: Yes
#
#     RFO_NO_PR21003643_Section 1:
#         Specific Prices: No
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Not Stated
#         Reasons for Tender Approval: N/A
#         Remarks Related to Price: N/A
#
#     v8 EVALUATION REPORT DEVELOPMENT OF MOBILE APPLICATION:
#         Specific Prices: Yes
#         Breakdown of Prices: Yes
#         Explanation of Prices: Yes
#         How Prices are Calculated: Yes
#         Tender Approval: Likely
#         Reasons for Tender Approval: Cost Effectiveness, Relevant Experience
#         Remarks Related to Price: Yes
#
# Based on this analysis:
#
#     Documents 5, 6, 7, and 9 meet all or most of the criteria.
#     Documents 1, 2, 3, 4, and 8 do not meet most of the criteria.
#
# Therefore, Documents 5, 6, 7, and 9 are the ones that fulfill the most criteria for us to use for price reasonableness evaluation, with four out of the nine documents meeting your specified criteria.

# %% [markdown]
# ## Documents Chosen
#
#
#
# 1. evaluation report development trial of COTS system
# 2. EVALUATION REPORT E LEARNING SYSTEM
# 3. Evaluation report for cloud based training aid software
# 4. EVALUATION REPORT DEVELOPMENT OF MOBILE APPLICATION

# %% [markdown]
# Evaluation of each sample tender evaluation report:
#
#     sample_tender_evaluation_report_1:
#         Specific Prices: Yes
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Yes
#         Reasons for Tender Approval: No
#         Remarks Related to Price: No
#
#     sample_tender_evaluation_report_2:
#         Specific Prices: No
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Yes
#         Reasons for Tender Approval: Yes
#         Remarks Related to Price: No
#
#     sample_tender_evaluation_report_3:
#         Specific Prices: Yes
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Yes
#         Reasons for Tender Approval: Yes (Lowest Price)
#         Remarks Related to Price: No
#
#     sample_tender_evaluation_report_4:
#         Specific Prices: Yes
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Yes
#         Reasons for Tender Approval: Yes
#         Remarks Related to Price: No
#
#     sample_tender_evaluation_report_5:
#         Specific Prices: No
#         Breakdown of Prices: No
#         Explanation of Prices: Yes
#         How Prices are Calculated: No
#         Tender Approval: Upcoming
#         Reasons for Tender Approval: No
#         Remarks Related to Price: No
#
#     sample_tender_evaluation_report_6:
#         Specific Prices: Yes
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Yes
#         Reasons for Tender Approval: Yes
#         Remarks Related to Price: No
#
#     sample_tender_evaluation_report_7:
#         Specific Prices: No
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Yes
#         Reasons for Tender Approval: No
#         Remarks Related to Price: No
#
#     sample_tender_evaluation_report_8:
#         Specific Prices: No
#         Breakdown of Prices: No
#         Explanation of Prices: No
#         How Prices are Calculated: No
#         Tender Approval: Not Stated
#         Reasons for Tender Approval: Not Stated
#         Remarks Related to Price: No
#
#     sample_tender_evaluation_report_9:
#         Specific Prices: Yes
#         Breakdown of Prices: Yes
#         Explanation of Prices: Yes
#         How Prices are Calculated: Yes
#         Tender Approval: Not Stated
#         Reasons for Tender Approval: Not Stated
#         Remarks Related to Price: No
